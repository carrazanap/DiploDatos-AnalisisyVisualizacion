# %% [markdown]
# <a href="https://colab.research.google.com/github/DiploDatos/AnalisisyVisualizacion/blob/master/03_Distribuciones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Diplomatura en Ciencia de Datos, Aprendizaje Automático y sus Aplicaciones**
#
# **Edición 2021**
#
# ---
#
# # Distribuciones

# %%
import io
import matplotlib
import matplotlib.pyplot as plt
import numpy
import pandas as pd
import seaborn

seaborn.set_context('talk')

# %% [markdown]
# ## Lectura del dataset
#
# En la notebook 00 se explican los detalles de la siguiente sección.

# %%
url = 'https://cs.famaf.unc.edu.ar/~mteruel/datasets/diplodatos/sysarmy_survey_2020_processed.csv'
df = pd.read_csv(url)

# %%
df[:3]
# Out:
#   profile_gender  profile_age work_country                    work_province  \
# 0          Mujer           26    Argentina  Ciudad Autónoma de Buenos Aires
# 1         Hombre           29    Argentina                       Corrientes
# 2          Mujer           22    Argentina  Ciudad Autónoma de Buenos Aires
#
#    profile_years_experience  work_years_in_company  \
# 0                       3.0                    3.0
# 1                       5.0                    2.0
# 2                       2.0                    0.0
#
#    work_years_in_current_position  work_people_in_charge_of  \
# 0                             3.0                         0
# 1                             2.0                         4
# 2                             0.0                         0
#
#   profile_studies_level profile_studies_level_state  ...  \
# 0         Universitario                    En curso  ...
# 1         Universitario                    En curso  ...
# 2            Secundario                  Completado  ...
#
#   work_has_violence_situations profile_sexual_orientation  \
# 0         En mi trabajo actual                 Homosexual
# 1                        Jamás               Heterosexual
# 2       En un trabajo anterior           Bisexual o queer
#
#   profile_has_disabilities profile_has_disabilities_hiring_difficulties  \
# 0                      NaN                                          NaN
# 1                   Visual                                           No
# 2                      NaN                                           No
#
#   company_employee_number                          company_main_activity  \
# 0                501-1000  Servicios / Consultoría de Software / Digital
# 1                 201-500                               Otras industrias
# 2               2001-5000                               Otras industrias
#
#   company_recommended company_diversity_policies  \
# 0                   7                          2
# 1                   8                          9
# 2                   6                          9
#
#                               company_extra_benefits  \
# 0  Capacitaciones y/o cursos, Comidas pagas / sub...
# 1  Horarios flexibles, Stock options / RSUs, Viát...
# 2  Clases de gimnasia online, Comidas pagas / sub...
#
#   company_best_companies_city
# 0                         NaN
# 1                         NaN
# 2                         NaN
#
# [3 rows x 48 columns]

# %% [markdown]
# # Variables Categóricas

# %%
fig = plt.figure(figsize=(8,6))
seaborn.countplot(df.profile_gender, color='steelblue')
# Out:
# /home/pablo/.local/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='profile_gender', ylabel='count'>

# %%
sorted_studies_levels = ['Primario', 'Secundario', 'Terciario', 'Universitario',
                         'Posgrado', 'Doctorado', 'Posdoctorado']
fig, axes = plt.subplots(ncols=2, figsize=(15,6))
g = seaborn.countplot(df.profile_studies_level, color='steelblue', ax=axes[0])
g = seaborn.countplot(df.profile_studies_level, color='steelblue', ax=axes[1],
                  order=sorted_studies_levels)
for ax in axes:
  ax.tick_params(labelrotation=30)
# Out:
# /home/pablo/.local/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /home/pablo/.local/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # Variables Numéricas

# %%
seaborn.__version__
# Out:
# '0.11.1'

# %%
salary_col='salary_monthly_BRUTO'
#salary_col='salary_monthly_NETO'

# %%
fig, axes = plt.subplots(nrows=2, figsize=(16, 10))
seaborn.histplot(df[salary_col], bins=100, ax=axes[0], color='gray')
axes[0].axvline(df[salary_col].mean(), color='orangered',
            linestyle='--', label='Media')
axes[0].axvline(df[salary_col].median(), color='indigo',
            linestyle='-.', label='Mediana')

filtered_df = df[df[salary_col] < 200000]
seaborn.histplot(filtered_df[salary_col], bins=100, ax=axes[1], color='gray')
axes[1].axvline(filtered_df[salary_col].mean(), color='orangered',
            linestyle='--', label='Media')
axes[1].axvline(filtered_df[salary_col].median(), color='indigo',
            linestyle='-.', label='Mediana')

axes[0].legend()
seaborn.despine()

# %% [markdown]
# #Varias Variables

# %% [markdown]
# ## Varias Categóricas

# %%
## Tabla de contingencia
pd.crosstab(df.profile_gender, df.profile_studies_level)#, normalize=True)
# Out:
# profile_studies_level  Doctorado  Posdoctorado  Posgrado  Primario  \
# profile_gender
# Hombre                        19             4       256         2
# Mujer                          8             0        85         0
# Otros                          3             0         1         0
#
# profile_studies_level  Secundario  Terciario  Universitario
# profile_gender
# Hombre                        424        970           3447
# Mujer                          24        158            667
# Otros                           1          7             19

# %%
fig = plt.figure(figsize=(10,6))
exp = pd.crosstab(df.profile_gender,
                  df.profile_studies_level)[sorted_studies_levels]
seaborn.heatmap(exp, annot=True, fmt='g')
# Out:
# <AxesSubplot:xlabel='profile_studies_level', ylabel='profile_gender'>

# %%
## Tabla de contingencia normalizada
pd.crosstab(df.profile_gender, df.profile_studies_level, normalize=True)
# Out:
# profile_studies_level  Doctorado  Posdoctorado  Posgrado  Primario  \
# profile_gender
# Hombre                  0.003117      0.000656  0.042002  0.000328
# Mujer                   0.001313      0.000000  0.013946  0.000000
# Otros                   0.000492      0.000000  0.000164  0.000000
#
# profile_studies_level  Secundario  Terciario  Universitario
# profile_gender
# Hombre                   0.069565   0.159147       0.565546
# Mujer                    0.003938   0.025923       0.109434
# Otros                    0.000164   0.001148       0.003117

# %%
fig = plt.figure(figsize=(8,6))
seaborn.countplot(df.profile_studies_level,  hue=df.profile_gender )
plt.xticks(rotation=45)
# Out:
# /home/pablo/.local/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# (array([0, 1, 2, 3, 4, 5, 6]),
#  [Text(0, 0, 'Universitario'),
#   Text(1, 0, 'Secundario'),
#   Text(2, 0, 'Posgrado'),
#   Text(3, 0, 'Terciario'),
#   Text(4, 0, 'Doctorado'),
#   Text(5, 0, 'Posdoctorado'),
#   Text(6, 0, 'Primario')])

# %% [markdown]
# ## Varias numéricas

# %%
max_age = 99
seaborn.pairplot(data=df[df.profile_age < max_age],
                 y_vars=['profile_age', 'salary_monthly_BRUTO'],
                 x_vars=['salary_monthly_NETO', 'salary_monthly_BRUTO'],
                 aspect=2, height=4)

# %%
seaborn.jointplot(data=df[df.profile_age < max_age], x='profile_age',
                  y='salary_monthly_NETO', kind='hex', height=6)
# Remove scietific notation
plt.ticklabel_format(style='plain', axis='y')

# %%
seaborn.jointplot(data=df[df.profile_age < max_age], x='profile_age',
                  y='salary_monthly_NETO', kind='kde', height=10)

# %%
max_age = 99
seaborn.pairplot(data=df[df.profile_age < max_age], y_vars=['salary_monthly_BRUTO'],
                 x_vars=['salary_monthly_NETO'],
                 aspect=2, height=4)

# %% [markdown]
# **Pregunta** ¿Cuáles le parece que son las ventajas de ver de a dos  (o más) variables simultáneamente?

# %% [markdown]
# ## Mixtas

# %%
filtered_df= df[df[salary_col] < 200000]
df_H= filtered_df[ filtered_df['profile_gender']=='Hombre']
df_M=filtered_df[ filtered_df['profile_gender']=='Mujer']

plt.hist(df_H[salary_col], color='orangered', bins=50)
plt.hist(df_M[salary_col], color='steelblue', bins=50)
plt.show()

# %%
seaborn.pairplot(data=df[df.profile_age < max_age], y_vars=['salary_monthly_NETO'],
                 x_vars=['salary_satisfaction'],
                 aspect=2, height=4)

# %% [markdown]
# Una desventaja de usar un pairplot para variables categóricas es la superposición de los puntos que tienen el mismo valor. Un gráfico que soluciona este problema es el `catplot`

# %%
seaborn.catplot(data=df[df.profile_age < max_age], y='salary_monthly_NETO',
                x='salary_satisfaction', height=4, aspect=2)

# %%
seaborn.jointplot(data=df[df.profile_age < max_age], x='profile_age',
                  y='salary_monthly_NETO', hue='profile_gender',
                  kind='kde', height=8)
# Out:
# /home/pablo/.local/lib/python3.7/site-packages/seaborn/distributions.py:1185: UserWarning: No contour levels were found within the data range.
#   **contour_kws,

# %% [markdown]
# # Práctico para resolver en clase
#
# 1. Analice las variables `'salary_monthly_BRUTO'` (salario mensual Bruto) y `'salary_monthly_NETO'` (salario Neto) en conjunto, que comentarios puede hacer al respecto?
#
# 2. Genere una nueva variable `'salary_monthly_DESCUENTOS'= 'salary_monthly_BRUTO'-'salary_monthly_NETO'`, es decir que contenga los descuentos mensuales.
#   1. ¿Qué concepto matemático utiliza para entender la nueva variable?
#   2. Calcule de dos fomas diferentes la media muestral de dicha variable.
#   2. Analice la distribución de los datos, su rango de valores e interprete. ¿Qué puede estar pasando? ¿Qué propone como solución?
#
# 3. Considerando toda la base:
#   1. ¿Que pregunta le interesaría responder?
#   2. ¿Que par de variables le conviene analizar en conjunto? Visualice su distribución conjunta.
#   3. ¿Qué medidas podrían resumir la información de la distribución de esas variables? visualícelas e interprete cada una.
#
# 4. Resuma:
#   1. Si está queriendo analizar el comportamiento conjunto de dos variables, ¿qué gráficos y medidas conviene utilizar?
#   2. ¿Y si ambas variables son numéricas?
#   3. ¿Y si ambas son categóricas?
#   4. ¿Y si una es categórica y la otra numérica?

# %% [markdown]
# # **DESARROLLO**

# %% [markdown]
# **EJERCICIO 1**
# 1. Analice las variables `'salary_monthly_BRUTO'` (salario mensual Bruto) y `'salary_monthly_NETO'` (salario Neto) en conjunto, que comentarios puede hacer al respecto?

# %%
max_age = 99

def plot_unity(xdata, ydata, **kwargs):
    mn = min(xdata.min(), ydata.min())
    mx = max(xdata.max(), ydata.max())
    points = numpy.linspace(mn, mx, 100)
    plt.gca().plot(points, points, color='k', marker=None,
            linestyle='--', linewidth=1.0)

ax = seaborn.pairplot(data=df[df.profile_age < max_age], y_vars=['salary_monthly_BRUTO'],
                 x_vars=['salary_monthly_NETO'],
                 aspect=2, height=4)
ax.map_offdiag(plot_unity)

# %% [markdown]
# * Visualizamos que las personas que se encuentran por debajo
# de la linea de 45° son personas que llenaron mal la encuesta ya que no existe la posibilidad de tener un neto mayor que el bruto
# * Las personas por encima de la linea de 45° tienen un porcentaje muy alto de retenciones

# %% [markdown]
# **EJERCICIO 2**
#
# 2. Genere una nueva variable `'salary_monthly_DESCUENTOS'= 'salary_monthly_BRUTO'-'salary_monthly_NETO'`, es decir que contenga los descuentos mensuales.
#   1. ¿Qué concepto matemático utiliza para entender la nueva variable?
#   2. Calcule de dos fomas diferentes la media muestral de dicha variable.
#   2. Analice la distribución de los datos, su rango de valores e interprete. ¿Qué puede estar pasando? ¿Qué propone como solución?

# %%
df["salary_monthly_DESCUENTOS"]= df['salary_monthly_BRUTO']-df['salary_monthly_NETO']

# %%
df["salary_monthly_DESCUENTOS"].head()
# Out:
# 0    10000.0
# 1    16000.0
# 2    33000.0
# 3    28000.0
# 4    34000.0
# Name: salary_monthly_DESCUENTOS, dtype: float64

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
df.head(1)
# Out:
#   profile_gender  profile_age work_country                    work_province  \
# 0          Mujer           26    Argentina  Ciudad Autónoma de Buenos Aires
#
#    profile_years_experience  work_years_in_company  \
# 0                       3.0                    3.0
#
#    work_years_in_current_position  work_people_in_charge_of  \
# 0                             3.0                         0
#
#   profile_studies_level profile_studies_level_state  \
# 0         Universitario                    En curso
#
#                           profile_career  \
# 0  Ingeniería en Sistemas de Información
#
#                        profile_university profile_specialization_courses  \
# 0  UTN - Universidad Tecnológica Nacional      Sí, los pagó un empleador
#
#   profile_open_source_contributions profile_programming_as_hobby   work_role  \
# 0                                No                           Sí  Consultant
#
#   tools_platform tools_programming_languages tools_frameworks  \
# 0        Ninguna                     Ninguno          Ninguno
#
#   tools_data_bases tools_qa_testing tools_IDEs tools_work_pc_os  \
# 0          Ninguna          Ninguna    Ninguno        GNU/Linux
#
#   tools_cellphone_os work_on_call_duty  salary_on_call_duty_charge  \
# 0            Android                No                         0.0
#
#   work_on_call_duty_charge_type work_contract_type  salary_monthly_BRUTO  \
# 0                         Bruto          Full-Time               53000.0
#
#    salary_monthly_NETO salary_in_usd  salary_satisfaction  \
# 0              43000.0           NaN                    1
#
#    salary_comparison_last_semester salary_has_bonus salary_bonus_tied_to  \
# 0                                1               No       No recibo bono
#
#   salary_inflation_adjustment_2020  \
# 0                               No
#
#    salary_percentage_inflation_adjustment_2020  \
# 0                                          0.0
#
#    salary_month_last_inflation_adjustment work_has_violence_situations  \
# 0                                       0         En mi trabajo actual
#
#   profile_sexual_orientation profile_has_disabilities  \
# 0                 Homosexual                      NaN
#
#   profile_has_disabilities_hiring_difficulties company_employee_number  \
# 0                                          NaN                501-1000
#
#                            company_main_activity  company_recommended  \
# 0  Servicios / Consultoría de Software / Digital                    7
#
#    company_diversity_policies  \
# 0                           2
#
#                                                                                                                                                                                                                                                 company_extra_benefits  \
# 0  Capacitaciones y/o cursos, Comidas pagas / subvencionadas, Cuota para universidad / posgrados, Descuentos varios (Mercado Pago, Clarín 365, Club La Nación, etc), Horarios flexibles, Lactario en la oficina, Licencia de paternidad/maternidad extendida, Viáticos
#
#   company_best_companies_city  salary_monthly_DESCUENTOS
# 0                         NaN                    10000.0

# %% [markdown]
# A. El concepto matematico que se usa es una funcion, donde la variable es el saldo de cada persona. Asi se obtiene por cada uno la diferencia entre el saldo bruto y el neto

# %% [markdown]
# B.

# %%
df["salary_monthly_DESCUENTOS"].describe() #-1396000.0 #2022000.0 2.022000
# Out:
# count    5.883000e+03
# mean     2.707367e+04
# std      6.682115e+04
# min     -1.396000e+06
# 25%      9.000000e+03
# 50%      1.700000e+04
# 75%      3.500000e+04
# max      2.022000e+06
# Name: salary_monthly_DESCUENTOS, dtype: float64

# %%
df["salary_monthly_DESCUENTOS"].mean()
# Out:
# 27073.667276219614

# %% [markdown]
# **EJERCICIO 3**
#
# 3. Considerando toda la base:
#   1. ¿Que pregunta le interesaría responder?
#   2. ¿Que par de variables le conviene analizar en conjunto? Visualice su distribución conjunta.
#   3. ¿Qué medidas podrían resumir la información de la distribución de esas variables? visualícelas e interprete cada una.

# %% [markdown]
# **EJERCICIO 4**
#
# 4. Resuma:
#   1. Si está queriendo analizar el comportamiento conjunto de dos variables, ¿qué gráficos y medidas conviene utilizar?
#   2. ¿Y si ambas variables son numéricas?
#   3. ¿Y si ambas son categóricas?
#   4. ¿Y si una es categórica y la otra numérica?
