# %% [markdown]
# <a href="https://colab.research.google.com/github/DiploDatos/AnalisisyVisualizacion/blob/master/Entregable_Parte_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Diplomatura en Ciencia de Datos, Aprendizaje Automático y sus Aplicaciones**
#
# **Edición 2021**
#
# ---
# ## Trabajo práctico entregable - Parte 1

# %%
import io
import matplotlib
import matplotlib.pyplot as plt
import numpy
import pandas as pd
import seaborn

seaborn.set_context('talk')

# %% [markdown]
# ## Lectura del dataset
#
# En la notebook 00 se explican los detalles de la siguiente sección.

# %%
url = 'https://cs.famaf.unc.edu.ar/~mteruel/datasets/diplodatos/sysarmy_survey_2020_processed.csv'
df = pd.read_csv(url)

# %%
df[:3]
# Out:
#   profile_gender  profile_age work_country                    work_province  \
# 0          Mujer           26    Argentina  Ciudad Autónoma de Buenos Aires
# 1         Hombre           29    Argentina                       Corrientes
# 2          Mujer           22    Argentina  Ciudad Autónoma de Buenos Aires
#
#    profile_years_experience  work_years_in_company  \
# 0                       3.0                    3.0
# 1                       5.0                    2.0
# 2                       2.0                    0.0
#
#    work_years_in_current_position  work_people_in_charge_of  \
# 0                             3.0                         0
# 1                             2.0                         4
# 2                             0.0                         0
#
#   profile_studies_level profile_studies_level_state  ...  \
# 0         Universitario                    En curso  ...
# 1         Universitario                    En curso  ...
# 2            Secundario                  Completado  ...
#
#   work_has_violence_situations profile_sexual_orientation  \
# 0         En mi trabajo actual                 Homosexual
# 1                        Jamás               Heterosexual
# 2       En un trabajo anterior           Bisexual o queer
#
#   profile_has_disabilities profile_has_disabilities_hiring_difficulties  \
# 0                      NaN                                          NaN
# 1                   Visual                                           No
# 2                      NaN                                           No
#
#   company_employee_number                          company_main_activity  \
# 0                501-1000  Servicios / Consultoría de Software / Digital
# 1                 201-500                               Otras industrias
# 2               2001-5000                               Otras industrias
#
#   company_recommended company_diversity_policies  \
# 0                   7                          2
# 1                   8                          9
# 2                   6                          9
#
#                               company_extra_benefits  \
# 0  Capacitaciones y/o cursos, Comidas pagas / sub...
# 1  Horarios flexibles, Stock options / RSUs, Viát...
# 2  Clases de gimnasia online, Comidas pagas / sub...
#
#   company_best_companies_city
# 0                         NaN
# 1                         NaN
# 2                         NaN
#
# [3 rows x 48 columns]

# %% [markdown]
# # Ejercicio 1 - Análisis descriptivo
#
# Responder a la pregunta: **¿Cuáles son los lenguajes de programación asociados a los mejores salarios?**
#
# Para ello:
# 1. Seleccionar las columnas relevantes para analizar.
# 2. Seleccionar las filas relevantes para analizar. Esto incluye la eliminación de valores extremos y erróneos, pero también puede enfocar el análisis en una sub-población. Por ejemplo, se pueden limitar a personas con un salario mayor que 10000 pesos, o a las personas que trabajan sólo en "Data Science", pero deben justificar su elección y reformular la pregunta inicial de ser necesario.
#   * Obtener una lista de los lenguajes de programación más populares. Decidir cuántos y cuáles seleccionan para incluir en el análisis.
#   * Para cada una de las otras columnas del punto anterior, elegir los rangos o valores seleccionan para incluir en el análisis.
# 3. Seleccionar métricas que ayuden a responder la pregunta, y los métodos para analizarlas. Elegir UNA de las siguientes opciones:
#   * Comparar las distribuciones de salario para cada lenguaje utilizando visualizaciones. Como la visualización es el producto final, debe ser clara y mostrar información relevante.
#   * Comparar medidas de estadística descriptiva sobre la distribución de salario para cada lenguaje. Sean creativos, la estadística descriptiva nos permite decir cosas como: "el 10% de los mejores sueldos los ganan, en su mayoría, programadores que saben kotlin!" (donde *mayoría* es un término medio engañoso que sólo significa más del 50%). Para comparar múltiples lenguajes, les recomendamos usar también visualizaciones.
#   * Comparar probabilidades. Por ejemplo: "Si sabés Python o Java, tenés un 30% más de chances de ganar arriba de 100K".
#
# Si lo consideran necesario, realicen varias iteraciones. Es decir, si encuentran que las distribuciones de los lenguajes de programación que seleccionaron inicialmente no son muy diferentes, pueden re-hacer el análisis usando sólo los lenguajes de programación que son diferentes.

# %% [markdown]
# **1.**

# %%
# complete here if you want to include more columns
relevant_columns = ['tools_programming_languages', 'salary_monthly_NETO']

# %%
df['salary_in_usd'].unique()
# Out:
# array([nan, 'Mi sueldo está dolarizado'], dtype=object)

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
df.loc[df['salary_in_usd']=='Mi sueldo está dolarizado'].tail(3)
# Out:
#      profile_gender  profile_age work_country  \
# 6079         Hombre           28    Argentina
# 6080         Hombre           30    Argentina
# 6084          Mujer           30    Argentina
#
#                         work_province  profile_years_experience  \
# 6079        Provincia de Buenos Aires                       2.0
# 6080                         San Luis                       5.0
# 6084  Ciudad Autónoma de Buenos Aires                       5.0
#
#       work_years_in_company  work_years_in_current_position  \
# 6079                    0.0                             2.0
# 6080                    2.0                             2.0
# 6084                    0.0                             0.0
#
#       work_people_in_charge_of profile_studies_level  \
# 6079                         0         Universitario
# 6080                         0             Terciario
# 6084                         0         Universitario
#
#      profile_studies_level_state                         profile_career  \
# 6079                  Incompleto  Ingeniería en Sistemas de Información
# 6080                  Incompleto            Tecnicatura en Programación
# 6084                  Completado                         Diseño Gráfico
#
#                                                             profile_university  \
# 6079  UNICEN - Universidad Nacional del Centro de la Provincia de Buenos Aires
# 6080                                                   Universidad de la punta
# 6084                                         UBA - Universidad de Buenos Aires
#
#      profile_specialization_courses profile_open_source_contributions  \
# 6079                             No                                No
# 6080        Sí, de forma particular                                Sí
# 6084                             No                                No
#
#      profile_programming_as_hobby                work_role  \
# 6079                           No                Developer
# 6080                           Sí  SysAdmin / DevOps / SRE
# 6084                           No           Recruiter / HR
#
#                                             tools_platform  \
# 6079                                                 Azure
# 6080  Docker, Kubernetes, Linux, OpenShift, Windows Server
# 6084                             Ninguna de las anteriores
#
#                                         tools_programming_languages  \
# 6079                    .NET, C#, CSS, HTML, Javascript, TypeScript
# 6080  Assembler, Bash/Shell, C++, HTML, Java, PHP, Python, SQL, VBA
# 6084                                      Ninguno de los anteriores
#
#                tools_frameworks                              tools_data_bases  \
# 6079       .NET Core, Bootstrap  Microsoft Azure (Tables, CosmosDB, SQL, etc)
# 6080  Ninguno de los anteriores        ElasticSearch, MongoDB, Percona Server
# 6084  Ninguno de los anteriores                     Ninguna de las anteriores
#
#                tools_qa_testing                              tools_IDEs  \
# 6079                    Postman       Visual Studio, Visual Studio Code
# 6080  Ninguna de las anteriores  NetBeans, Notepad++, Sublime Text, Vim
# 6084  Ninguna de las anteriores               Ninguno de los anteriores
#
#      tools_work_pc_os tools_cellphone_os work_on_call_duty  \
# 6079          Windows            Android                No
# 6080        GNU/Linux            Android                No
# 6084            macOS                iOS                No
#
#       salary_on_call_duty_charge work_on_call_duty_charge_type  \
# 6079                         0.0                          Neto
# 6080                         0.0                         Bruto
# 6084                         0.0       Porcentaje de mi sueldo
#
#      work_contract_type  salary_monthly_BRUTO  salary_monthly_NETO  \
# 6079          Full-Time              100000.0              80000.0
# 6080          Full-Time              580000.0             391000.0
# 6084          Full-Time               99000.0              77800.0
#
#                   salary_in_usd  salary_satisfaction  \
# 6079  Mi sueldo está dolarizado                    3
# 6080  Mi sueldo está dolarizado                    2
# 6084  Mi sueldo está dolarizado                    3
#
#       salary_comparison_last_semester    salary_has_bonus  \
# 6079                                4                  No
# 6080                                2  Menos de un sueldo
# 6084                                3           Un sueldo
#
#        salary_bonus_tied_to salary_inflation_adjustment_2020  \
# 6079         No recibo bono                      Más de tres
# 6080  Mix de las anteriores                               No
# 6084  Mix de las anteriores                               No
#
#       salary_percentage_inflation_adjustment_2020  \
# 6079                                         35.0
# 6080                                          0.0
# 6084                                          0.0
#
#       salary_month_last_inflation_adjustment work_has_violence_situations  \
# 6079                                       7                        Jamás
# 6080                                       1       En un trabajo anterior
# 6084                                       0       En un trabajo anterior
#
#      profile_sexual_orientation profile_has_disabilities  \
# 6079               Heterosexual                      NaN
# 6080               Heterosexual                      NaN
# 6084               Heterosexual                      NaN
#
#      profile_has_disabilities_hiring_difficulties company_employee_number  \
# 6079                                          NaN                 201-500
# 6080                                           No                501-1000
# 6084                                          NaN                 101-200
#
#                               company_main_activity  company_recommended  \
# 6079  Servicios / Consultoría de Software / Digital                   10
# 6080  Servicios / Consultoría de Software / Digital                   10
# 6084  Servicios / Consultoría de Software / Digital                    8
#
#       company_diversity_policies  \
# 6079                           8
# 6080                          10
# 6084                           5
#
#                                                                                                                                                                      company_extra_benefits  \
# 6079                                                                                                                                                              Ninguna de las anteriores
# 6080  Clases de idiomas, Estacionamiento gratuito / subvencionado, Horarios flexibles, Licencia de paternidad/maternidad extendida, Vacaciones flexibles (adicionales a las reglamentarias)
# 6084                                                                                                                       Capacitaciones y/o cursos, Clases de idiomas, Horarios flexibles
#
#             company_best_companies_city
# 6079                                NaN
# 6080  Init ag, Computercenter, DKB, n26
# 6084                                NaN

# %% [markdown]
# **2.**

# %%
df.loc[df["work_role"]=="Developer"].head(3)
# Out:
#   profile_gender  profile_age work_country                    work_province  \
# 1         Hombre           29    Argentina                       Corrientes
# 4         Hombre           32    Argentina  Ciudad Autónoma de Buenos Aires
# 5         Hombre           25    Argentina  Ciudad Autónoma de Buenos Aires
#
#    profile_years_experience  work_years_in_company  \
# 1                       5.0                    2.0
# 4                       9.0                    6.0
# 5                       1.0                    0.0
#
#    work_years_in_current_position  work_people_in_charge_of  \
# 1                             2.0                         4
# 4                             6.0                         0
# 5                             0.0                         0
#
#   profile_studies_level profile_studies_level_state  \
# 1         Universitario                    En curso
# 4         Universitario                    En curso
# 5             Terciario                  Incompleto
#
#                               profile_career  \
# 1      Ingeniería en Sistemas de Información
# 4  Licenciatura en Ciencias dela Computación
# 5       Tecnicatura Superior en Programación
#
#                        profile_university  \
# 1  UTN - Universidad Tecnológica Nacional
# 4       UBA - Universidad de Buenos Aires
# 5  UTN - Universidad Tecnológica Nacional
#
#                        profile_specialization_courses  \
# 1  Sí, de forma particular, Sí, los pagó un empleador
# 4                                                  No
# 5                                                  No
#
#   profile_open_source_contributions profile_programming_as_hobby  work_role  \
# 1                                No                           Sí  Developer
# 4                                No                           Sí  Developer
# 5                                No                           Sí  Developer
#
#                              tools_platform  \
# 1  Docker, Google Cloud Platform/App Engine
# 4                       Amazon Web Services
# 5                                   Ninguna
#
#               tools_programming_languages          tools_frameworks  \
# 1                HTML, Javascript, Python            Django, jQuery
# 4  CSS, HTML, Javascript, SQL, TypeScript          Angular, Node.js
# 5                        Java, Javascript  Node.js, React.js, Spark
#
#                   tools_data_bases      tools_qa_testing  \
# 1      Informix, MySQL, PostgreSQL               Ninguna
# 4  Amazon DynamoDB, MongoDB, MySQL                  Jest
# 5                            MySQL  Jest, JUnit, Postman
#
#                                             tools_IDEs tools_work_pc_os  \
# 1  IPython / Jupyter, Sublime Text, Visual Studio Code        GNU/Linux
# 4                                                  Vim            macOS
# 5                         IntelliJ, Visual Studio Code            macOS
#
#   tools_cellphone_os work_on_call_duty  salary_on_call_duty_charge  \
# 1            Android                No                         0.0
# 4            Android                No                         0.0
# 5            Android                No                         0.0
#
#   work_on_call_duty_charge_type work_contract_type  salary_monthly_BRUTO  \
# 1                         Bruto          Full-Time               79000.0
# 4       Porcentaje de mi sueldo          Full-Time              140000.0
# 5                         Bruto          Full-Time               54000.0
#
#    salary_monthly_NETO salary_in_usd  salary_satisfaction  \
# 1              63000.0           NaN                    2
# 4             106000.0           NaN                    1
# 5              44000.0           NaN                    2
#
#    salary_comparison_last_semester    salary_has_bonus  \
# 1                                2  Menos de un sueldo
# 4                                1  Menos de un sueldo
# 5                                2                  No
#
#          salary_bonus_tied_to salary_inflation_adjustment_2020  \
# 1  Performance de la compañía                              Uno
# 4      Performance individual                               No
# 5              No recibo bono                              Uno
#
#    salary_percentage_inflation_adjustment_2020  \
# 1                                         10.0
# 4                                          0.0
# 5                                         15.0
#
#    salary_month_last_inflation_adjustment work_has_violence_situations  \
# 1                                       1                        Jamás
# 4                                       0                        Jamás
# 5                                       5                        Jamás
#
#   profile_sexual_orientation profile_has_disabilities  \
# 1               Heterosexual                   Visual
# 4               Heterosexual                      NaN
# 5               Heterosexual                      NaN
#
#   profile_has_disabilities_hiring_difficulties company_employee_number  \
# 1                                           No                 201-500
# 4                                          NaN                   11-50
# 5                                           No                  10001+
#
#                            company_main_activity  company_recommended  \
# 1                               Otras industrias                    8
# 4  Servicios / Consultoría de Software / Digital                    6
# 5                    Producto basado en Software                    8
#
#    company_diversity_policies  \
# 1                           9
# 4                           6
# 5                           8
#
#                                                                            company_extra_benefits  \
# 1                                              Horarios flexibles, Stock options / RSUs, Viáticos
# 4  Clases de idiomas, Horarios flexibles, Vacaciones flexibles (adicionales a las reglamentarias)
# 5                    Clases de gimnasia online, Clases de idiomas, Comidas pagas / subvencionadas
#
#   company_best_companies_city               cured_programming_languages
# 1                         NaN                [html, javascript, python]
# 4                         NaN  [css, html, javascript, sql, typescript]
# 5                         NaN                        [java, javascript]

# %%
df['salary_monthly_NETO'].quantile([.90,.95, .98, .99, .995, .998])
# Out:
# 0.900    150000.00
# 0.950    210000.00
# 0.980    370000.00
# 0.990    491800.00
# 0.995    650000.00
# 0.998    955289.52
# Name: salary_monthly_NETO, dtype: float64

# %%
plt.figure(figsize=(12, 4))
max_limit = df['salary_monthly_NETO'].quantile(.90)
seaborn.boxenplot(x=df[df['salary_monthly_NETO'] < max_limit]['salary_monthly_NETO'])
# Out:
# <AxesSubplot:xlabel='salary_monthly_NETO'>

# %%
fig, axes = plt.subplots(figsize=(12, 12), nrows=3)
max_limit = df['salary_monthly_NETO'].quantile(.90)
data = df[df['salary_monthly_NETO'] < max_limit]['salary_monthly_NETO']
seaborn.histplot(x=data, ax=axes[0])
seaborn.boxplot(x=data, ax=axes[1])
seaborn.boxenplot(x=data, ax=axes[2])
# Out:
# <AxesSubplot:xlabel='salary_monthly_NETO'>

# %% [markdown]
# **Rango itercuartílico**

# %%
def clean_outliers(dataset, column_name):
    """Returns dataset removing the outlier rows from column @column_name."""
    interesting_col = dataset[column_name]
    # Here we can remove the outliers from both ends, or even add more restrictions.
    mask_outlier = (
        numpy.abs(interesting_col - interesting_col.mean()) <= (2.5 * interesting_col.std()))
    return dataset[mask_outlier]

# %%
fig, axes = plt.subplots(figsize=(12, 12), nrows=3)
max_limit = df['salary_monthly_NETO'].quantile(.98)
data = clean_outliers(df, 'salary_monthly_NETO')['salary_monthly_NETO']
seaborn.histplot(x=data, ax=axes[0])
seaborn.boxplot(x=data, ax=axes[1])
seaborn.boxenplot(x=data, ax=axes[2])
# Out:
# <AxesSubplot:xlabel='salary_monthly_NETO'>

# %%
df[df['salary_monthly_NETO'] > df['salary_monthly_NETO'].quantile(0.98)].head(3)
# Out:
#     profile_gender  profile_age work_country                    work_province  \
# 261         Hombre           37    Argentina  Ciudad Autónoma de Buenos Aires
# 267          Otros           40    Argentina        Provincia de Buenos Aires
# 303         Hombre           34    Argentina        Provincia de Buenos Aires
#
#      profile_years_experience  work_years_in_company  \
# 261                      21.0                   10.0
# 267                      20.0                    0.0
# 303                      10.0                    2.0
#
#      work_years_in_current_position  work_people_in_charge_of  \
# 261                            10.0                        17
# 267                             0.0                         0
# 303                             8.0                         0
#
#     profile_studies_level profile_studies_level_state  \
# 261         Universitario                  Incompleto
# 267         Universitario                  Incompleto
# 303         Universitario                  Incompleto
#
#                             profile_career  \
# 261                                    NaN
# 267  Ingeniería en Sistemas de Información
# 303              Ingeniería en Informática
#
#                                                            profile_university  \
# 261                                                                       NaN
# 267  UNICEN - Universidad Nacional del Centro de la Provincia de Buenos Aires
# 303                                UADE - Universidad Argentina De la Empresa
#
#     profile_specialization_courses profile_open_source_contributions  \
# 261                             No                                Sí
# 267                             No                                No
# 303        Sí, de forma particular                                No
#
#     profile_programming_as_hobby     work_role  \
# 261                           Sí  VP / C-Level
# 267                           Sí     Developer
# 303                           Sí     Developer
#
#                                                                         tools_platform  \
# 261  Docker, Firebase, Google Cloud Platform/App Engine, Kubernetes, Linux, Serverless
# 267                                                         Amazon Web Services, Linux
# 303                                                                             Docker
#
#                                         tools_programming_languages  \
# 261  Bash/Shell, Go, HTML, Javascript, Perl, PHP, Python, Ruby, SQL
# 267                                         Bash/Shell, Python, SQL
# 303                                                        .NET, C#
#
#             tools_frameworks  \
# 261  jQuery, Rails, React.js
# 267         Django, React.js
# 303                .NET Core
#
#                                                                       tools_data_bases  \
# 261  Google Cloud Storage, MariaDB, MySQL, Percona Server, PostgreSQL, ProxySQL, Redis
# 267                                                  MongoDB, Neo4j, PostgreSQL, Redis
# 303                                                                         PostgreSQL
#
#     tools_qa_testing                                          tools_IDEs  \
# 261          Ninguna                                             Vi, Vim
# 267          Ninguna                    PyCharm, Vim, Visual Studio Code
# 303            NUnit  Visual Studio, Visual Studio Code, WebStorm, Rider
#
#     tools_work_pc_os tools_cellphone_os work_on_call_duty  \
# 261        GNU/Linux            Android                No
# 267            macOS                iOS                No
# 303            macOS            Android                No
#
#      salary_on_call_duty_charge work_on_call_duty_charge_type  \
# 261                         0.0       Porcentaje de mi sueldo
# 267                         0.0                         Bruto
# 303                         0.0       Porcentaje de mi sueldo
#
#                 work_contract_type  salary_monthly_BRUTO  salary_monthly_NETO  \
# 261                      Full-Time              800000.0             500000.0
# 267  Remoto (empresa de otro país)              420000.0             380000.0
# 303  Remoto (empresa de otro país)              480000.0             430000.0
#
#                  salary_in_usd  salary_satisfaction  \
# 261                        NaN                    4
# 267  Mi sueldo está dolarizado                    4
# 303  Mi sueldo está dolarizado                    4
#
#      salary_comparison_last_semester salary_has_bonus    salary_bonus_tied_to  \
# 261                                4       3+ sueldos   Mix de las anteriores
# 267                                4        Un sueldo  Performance individual
# 303                                4               No          No recibo bono
#
#     salary_inflation_adjustment_2020  \
# 261                              Uno
# 267                               No
# 303                               No
#
#      salary_percentage_inflation_adjustment_2020  \
# 261                                         20.0
# 267                                          0.0
# 303                                          0.0
#
#      salary_month_last_inflation_adjustment work_has_violence_situations  \
# 261                                       4                        Jamás
# 267                                       0                        Jamás
# 303                                       0       En un trabajo anterior
#
#     profile_sexual_orientation profile_has_disabilities  \
# 261               Heterosexual                      NaN
# 267          ¿Qué les importa?                      NaN
# 303           Bisexual o queer                      NaN
#
#     profile_has_disabilities_hiring_difficulties company_employee_number  \
# 261                                          NaN              5001-10000
# 267                                           No                    1-10
# 303                                           No                 201-500
#
#                              company_main_activity  company_recommended  \
# 261                    Producto basado en Software                    9
# 267                    Producto basado en Software                    9
# 303  Servicios / Consultoría de Software / Digital                   10
#
#      company_diversity_policies  \
# 261                           9
# 267                          10
# 303                           7
#
#                                                                                                                                                                                                                                        company_extra_benefits  \
# 261  Abono de celular, Capacitaciones y/o cursos, Clases de idiomas, Comidas pagas / subvencionadas, Descuentos varios (Mercado Pago, Clarín 365, Club La Nación, etc), Horarios flexibles, Licencia de paternidad/maternidad extendida, Stock options / RSUs
# 267                                                                                                                                 Capacitaciones y/o cursos, Clases de idiomas, Horarios flexibles, Vacaciones flexibles (adicionales a las reglamentarias)
# 303                                                                                                                                                                                                             Capacitaciones y/o cursos, Horarios flexibles
#
#     company_best_companies_city
# 261                         NaN
# 267                         NaN
# 303                         NaN

# %%
df["work_role"].value_counts()
# Out:
# Developer                                           2402
# SysAdmin / DevOps / SRE                              689
# Technical Leader                                     399
# QA / Tester                                          254
# Manager / Director                                   231
#                                                     ...
# Infraestructura, Networking, SysAdmin, DBManager       1
# SOPORTE DE APP                                         1
# tecnico                                                1
# Técnico de Desktop                                     1
# Application Analyst                                    1
# Name: work_role, Length: 334, dtype: int64

# %% [markdown]
# ### Conteo de frecuencias de los lenguajes de programación
#
# La columna que contiene información sobre los lenguajes de programación utilizados es `tools_programming_languages`. Sus valores son strings con los lenguajes seleccionados separados por comas.

# %%
df.tools_programming_languages[:3]
# Out:
# 0                     Ninguno
# 1    HTML, Javascript, Python
# 2                     Ninguno
# Name: tools_programming_languages, dtype: object

# %% [markdown]
# Las siguientes celdas de código separan estos lenguajes de programación y cuentan la frecuencia con la que aparecen.
#
# No es necesario entender este código en profundidad, aunque sí es un buen ejercicio.

# %%
# Convert the comma-separated string of languages to a list of string.
# Remove 'ninguno de los anteriores' option, spaces and training commas.
def split_languages(languages_str):
  if not isinstance(languages_str, str):
    return []
  # Remove 'other' option
  languages_str = languages_str.lower()\
    .replace('ninguno de los anteriores', '')
  # Split string into list of items
  # Remove spaces and commas for each item
  return [lang.strip().replace(',', '')
          for lang in languages_str.split()]

# Create a new column with the list of languages
df.loc[:, 'cured_programming_languages'] = df.tools_programming_languages\
    .apply(split_languages)
if 'cured_programming_languages' not in relevant_columns:
    relevant_columns.append('cured_programming_languages') 

# Duplicate each row of df for each programming language
# mentioned in the response.
# We only include in df_lang the columns we are going to analyze later, so we
# don't duplicate innecesary information.
df_lang = df.cured_programming_languages\
    .apply(pd.Series).stack()\
    .reset_index(level=-1, drop=True).to_frame()\
    .join(df[relevant_columns])\
    .rename(columns={0: 'programming_language'})
# Horrible programming style! But a lot of data science code can be written with
# as concatenations of functions (pipelines), and there's no elegant way of
# doing that on Python.
df_lang[:5]
# Out:
#   programming_language tools_programming_languages  salary_monthly_NETO  \
# 0              ninguno                     Ninguno              43000.0
# 1                 html    HTML, Javascript, Python              63000.0
# 1           javascript    HTML, Javascript, Python              63000.0
# 1               python    HTML, Javascript, Python              63000.0
# 2              ninguno                     Ninguno             127000.0
#
#   cured_programming_languages
# 0                   [ninguno]
# 1  [html, javascript, python]
# 1  [html, javascript, python]
# 1  [html, javascript, python]
# 2                   [ninguno]

# %% [markdown]
# En la columna `programming_language` se encuentra cada lenguaje por separado. Notar que si una respuesta contenía 3 lenguajes, como `"HTML, Javascript, Python"`, la fila ha sido replicada 3 veces. Por ello, hay tres filas con índice 1.

# %%
language_count = df_lang.programming_language.value_counts()\
    .reset_index()\
    .rename(columns={'index': 'language', 'programming_language': 'frequency'})
language_count[:10]
# Out:
#      language  frequency
# 0  javascript       2513
# 1         sql       2154
# 2        html       1861
# 3      python       1475
# 4        java       1453
# 5         css       1247
# 6  bash/shell        993
# 7         php        891
# 8        .net        823
# 9  typescript        779

# %% [markdown]
# ## Filtrado de lenguajes relevantes
#
# El siguiente código permite seleccionar sólo las filas donde el valor de la columna `programming_language` se encuentre en la lista `interesting_languages`.

# %%
# Filter out languages that we want to exclude
# Complete here with your selected list.
interesting_languages = ["python","javascript","sql","java"]
filtered_df_lang = df_lang[df_lang.programming_language.isin(interesting_languages)]
filtered_df_lang[:5]
# Out:
#   programming_language  \
# 1           javascript
# 1               python
# 3                 java
# 3           javascript
# 3               python
#
#                                     tools_programming_languages  \
# 1                                      HTML, Javascript, Python
# 1                                      HTML, Javascript, Python
# 3  Bash/Shell, C, CSS, HTML, Java, Javascript, PHP, Python, SQL
# 3  Bash/Shell, C, CSS, HTML, Java, Javascript, PHP, Python, SQL
# 3  Bash/Shell, C, CSS, HTML, Java, Javascript, PHP, Python, SQL
#
#    salary_monthly_NETO  \
# 1              63000.0
# 1              63000.0
# 3             102000.0
# 3             102000.0
# 3             102000.0
#
#                                       cured_programming_languages
# 1                                      [html, javascript, python]
# 1                                      [html, javascript, python]
# 3  [bash/shell, c, css, html, java, javascript, php, python, sql]
# 3  [bash/shell, c, css, html, java, javascript, php, python, sql]
# 3  [bash/shell, c, css, html, java, javascript, php, python, sql]

# %% [markdown]
# # Ejercicio 2 - Densidades y varias varialbes
#
# Responder a la pregunta general: **¿Que herramientas (prácticas y teóricas) són útiles para explorar la base, descubrir patrones, asociaciones?**
#
# Para ello considere (igual al ejercicio Anterior):
# 1. Seleccionar las columnas relevantes para analizar.
# 2. Seleccionar las filas relevantes para analizar. Esto incluye la eliminación de valores extremos y erróneos, pero también puede enfocar el análisis en sub-poblaciones.

# %% [markdown]
# ## a) Densidad conjunta
#
# Que herramientas visuales y modelos puede utilizar para estudiar la distribución y comportamiento de sus datos?
#
# Elija tres variables numéricas y 2 variables categóricas. Visualice la base según varias de las variables elegidas. Puede describir de alguna forma el comportamiento de sus datos? Que herramientas utilizaría? Describa

# %% [markdown]
# ## b) Asociación
#
# * Necesitamos decidir si sacar o no la columna de salario bruto. Para hacer la encuesta más simple.
# ¿Existe una correlación entre el salario bruto y el neto? Que abordaje y medidas usaría

# %% [markdown]
# ## c) Densidad condicional
#
# Estudie la distribución del salario según el nivel de estudio.
#
# Separe la población según el nivel de estudio (elija dos subpoblaciones numerosas) y grafique de manera comparativa ambos histogramas de la variable `'salary_monthly_NETO'`
# ¿Considera que ambas variables son independientes?
# ¿Qué analizaría al respecto?
#
# Calcule medidas de centralización y dispersión para cada subpoblación

# %% [markdown]
# ## d) Densidad Conjunta condicional
#
# Elija dos variables numéricas y una categórica.
# Estudie la dispersión (scatterplot) de las dos variables discriminando en color por la variable categórica (ayuda: hue en seaborn)
